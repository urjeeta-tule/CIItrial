# %%
#!/usr/bin/env python

# %%
# coding: utf-8

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv('Data_reordered.csv')
# Out:
# C:\Users\QJ661TL\AppData\Local\Temp\ipykernel_36856\70166853.py:1: DtypeWarning: Columns (127,157,222,223,230) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('Data_reordered.csv')

# %%
pd.set_option("display.max_columns", None)

# %%
type = input('Which datatype do you want:Agent, Customer or Call?\n')
# Out:
# Which datatype do you want:Agent, Customer or Call?
# Agent

# %%
if type == 'Agent':
    display(df1[df1.columns[0:127]])
elif type == 'Customer':
    display(df1[df1.columns[222:239]])
else:
    display(df1[df1.columns[127:222]])
# Out:
#       score_slab_overall_adherence_score            Agent Name  Unnamed: 2  \
# 0                               Very Low       Matthew Jackson         NaN
# 1                               Very Low       Timothy Purcell         NaN
# 2                               Very Low      Kathryn Brookins         NaN
# 3                               Very Low      Khalil Ferdinand         NaN
# 4                               Very Low       Blake Edinburgh         NaN
# ...                                  ...                   ...         ...
# 89670                           Very Low        Lisette Castro         NaN
# 89671                           Very Low  Monica Vasquez-Gomez         NaN
# 89672                           Very Low           Debbie Snow         NaN
# 89673                           Very Low         Matthew Lewis         NaN
# 89674                           Very Low        Vanessa Medina         NaN
#
#                 Manager                 Supervisor  \
# ...
